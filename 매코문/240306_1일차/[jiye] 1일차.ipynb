# %% [markdown]
# ## 0306

# %% [markdown]
# ### [정렬-K번째 수](https://school.programmers.co.kr/learn/courses/30/lessons/42748)

# %% [markdown]
# ![alt text](image.png)

# %%
array=[1,5,2,6,3,7,4]
commands=[[2,5,3],[4,4,1],[1,7,3]]

# %%
answer=[]
for com in commands:
    answer.append(sorted(array[com[0]-1:com[1]])[com[2]-1])

# %%
answer
# Out:
# [5, 6, 3]

# %% [markdown]
# ### [정렬-가장 큰 수](https://school.programmers.co.kr/learn/courses/30/lessons/42746)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
numbers=[6,10,2]

# %%
temp_list=[]
for number in numbers:
    temp_list.append(int(list(str(number))[0]))

# %%
sorted(temp_list,reverse=True)
# Out:
# [6, 2, 1]
